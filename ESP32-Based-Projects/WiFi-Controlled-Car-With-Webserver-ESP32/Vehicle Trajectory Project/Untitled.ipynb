 ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
import yaml
import numpy as np

# Your trajectory data
trajectory_x = np.array([[ 0.00000000e+00 , 6.35607069e-02, -1.47715962e-02, -1.67218980e-02,
  -1.41088565e-01,  7.99651342e-03, -1.33174728e-01, -3.02890376e-01,
  -6.68619256e-01, -8.37532495e-01, -8.48986955e-01, -9.43254124e-01,
  -8.88580813e-01, -1.02561230e+00, -1.30486807e+00, -1.71412488e+00,
  -2.04368775e+00, -2.50696154e+00, -2.90820131e+00, -3.25021730e+00,
  -3.59271650e+00, -4.05219100e+00, -4.57077551e+00, -5.17073745e+00,
  -5.77602167e+00, -6.24492958e+00, -6.81031773e+00, -7.33277811e+00,
  -7.79124421e+00, -8.33665164e+00, -8.92995755e+00, -9.50870359e+00,
  -1.02620709e+01, -1.10570187e+01, -1.19050994e+01, -1.28496840e+01,
  -1.37886535e+01, -1.47450900e+01, -1.57156365e+01, -1.67030576e+01,
  -1.76944593e+01, -1.86765656e+01, -1.96716520e+01, -2.06690965e+01,
  -2.16684049e+01, -2.26411005e+01, -2.35899105e+01, -2.45322401e+01,
  -2.54575829e+01, -2.63074163e+01, -2.71426813e+01, -2.79833668e+01]])
trajectory_y = np.array( [[ 0. ,        -0.06171829, -0.04547649, -0.01822338,  0.01576022, -0.06565506,
  -0.00725287,  0.00542443,  0.05341401,  0.03567593,  0.06775617,  0.09041093,
   0.06850642,  0.21324575,  0.29198446, 0.32879371,  0.32369601, 0.33397941,
   0.41217373,  0.46804135,  0.54508339,  0.594214,   0.70239923,  0.73852337,
   0.72040186,  0.7033766,  0.7405495,   0.70266422,  0.70958438,  0.79754325,
   0.83729865, 0.88368292,  0.94149262,  0.92954711, 0.97529991,  1.0165419,
   1.02311286, 1.08069455,  1.09902641,  1.12124644,  1.16495326,  1.23451476,
   1.28586778,  1.30452009,  1.33988604,  1.2689607,   1.23665064,  1.30197932,
   1.23065367,  1.1599528,   1.20821583,  1.1554376 ]])
trajectory_z = np.array( [[ 0.     ,     0.99606771 , 1.9928627 ,  2.99248937 , 3.98414356 , 4.96961056,
   5.95787159,  6.94328312,  7.87276651,  8.85823781,  9.85765747, 10.85294661,
  11.85121061, 12.83114576, 13.78812874, 14.69980519, 15.64392506, 16.5300806,
  17.44270993, 18.38074185, 19.31709585, 20.20392693, 21.05208144, 21.851294,
  22.64709713, 23.53018009, 24.35416699, 25.20598849, 26.09467344, 26.92821646,
  27.73221124, 28.54639889, 29.20145286, 29.80801315, 30.33590122, 30.66156825,
  31.00550576, 31.29171112, 31.53192678, 31.68847002, 31.81180847, 31.98681814,
  32.07146994, 32.14043793, 32.15192312, 32.37290491, 32.6870955 , 33.01534379,
  33.38770581, 33.90999368, 34.45771899, 34.99666449]])

# Convert NumPy arrays to lists
trajectory_x_list = trajectory_x.tolist()
trajectory_y_list = trajectory_y.tolist()
trajectory_z_list = trajectory_z.tolist()

# Create a dictionary with keys as "Trajectory X", "Trajectory Y", and "Trajectory Z"
data_dict = {"Trajectory X": trajectory_x_list, "Trajectory Y": trajectory_y_list, "Trajectory Z": trajectory_z_list}

# Specify the file path
output_file_path = 'output.yaml'

# Write data to YAML file
with open(output_file_path, 'w') as output_file:
    yaml.dump(data_dict, output_file, default_flow_style=False)

print(f'Trajectory data has been saved to {output_file_path} in YAML format.')
# Out:
# Trajectory data has been saved to output.yaml in YAML format.
